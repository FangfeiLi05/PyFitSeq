# %%
import numpy as np
import pandas as pd

x_true = np.array(pd.read_csv('result_EvoSimulation_Input_Log.csv')['Fitness'], dtype=float)
x_estimate = np.array(pd.read_csv('result_FitSeq.csv')['Estimated_Fitness'], dtype=float)

# %%
import matplotlib.pyplot as plt

plt.plot(x_true, x_estimate, '.', color='r')

plt.xlim(-0.5, 0.35)
plt.ylim(-0.5, 0.35)
# Out:
# (-0.5, 0.35)
